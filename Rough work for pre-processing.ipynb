# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Exchange_Rates.csv")
df
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
df['Currency'].unique()
# Out:
# array(['USD', 'CAD', 'AUD', 'EUR', 'GBP'], dtype=object)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
Exchange_rates_df = df
Exchange_rates_df
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Stores.csv")
df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df['Open Date'] = pd.to_datetime(df['Open Date'])

# %%
df['State'].unique()
# Out:
# array(['Australian Capital Territory', 'Northern Territory',
#        'South Australia', 'Tasmania', 'Victoria', 'Western Australia',
#        'New Brunswick', 'Newfoundland and Labrador',
#        'Northwest Territories', 'Nunavut', 'Yukon', 'Basse-Normandie',
#        'Corse', 'Franche-Comté', 'La Réunion', 'Limousin', 'Martinique',
#        'Mayotte', 'Berlin', 'Brandenburg', 'Freie Hansestadt Bremen',
#        'Freistaat Thüringen', 'Hamburg', 'Hessen',
#        'Mecklenburg-Vorpommern', 'Saarland', 'Sachsen-Anhalt',
#        'Caltanissetta', 'Enna', 'Pesaro', 'Drenthe', 'Flevoland',
#        'Friesland', 'Groningen', 'Zeeland', 'Armagh', 'Ayrshire',
#        'Belfast', 'Blaenau Gwent', 'Dungannon and South Tyrone',
#        'Fermanagh', 'North Down', 'Alaska', 'Arkansas', 'Connecticut',
#        'Delaware', 'Hawaii', 'Idaho', 'Iowa', 'Kansas', 'Maine',
#        'Mississippi', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
# ...

# %%
df = df.fillna(0)   # for online store the square meters column is nan , so we give 0

# %%
Stores_df = df

# %%
Stores_df.isna().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
Stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Products.csv")
df
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
df['Unit Cost USD'] = df['Unit Cost USD'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df['Unit Price USD'] = df['Unit Price USD'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
Products_df = df

# %%
df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Customers.csv")   
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14092\2305093938.py in <module>
# ----> 1 df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Customers.csv")
#       2 df
#
# ...

# %%
#The UnicodeDecodeError usually occurs when the file you're trying to read contains characters that aren’t encoded in UTF-8, which is the default encoding for pandas.read_csv(). 
#To fix this, you can try specifying a different encoding when reading the CSV file.
#Try with ISO-8859-1 or latin1 Encoding: This encoding is more lenient and can often handle files that throw errors with UTF-8.

df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Customers.csv", encoding='ISO-8859-1')   
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df[df['State Code'].isna()]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
'Napoli' in df['State Code'].unique()
# Out:
# False

# %%
# Napoli state has no state code mentioned in the df , so we give the same state name in state code 
df['State Code'] = df['State Code'].fillna('Napoli')

# %%
df.isna().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df['Zip Code'] = df['Zip Code'].astype('int64')
# we treid this but zip codes contain alphabets also so we keeep it in string only
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14092\407857717.py in <module>
# ----> 1 df['Zip Code'] = df['Zip Code'].astype('int64')
#       2 # we treid this but zip codes contain alphabets also so we keeep it in string only
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
# ...

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Canada', 'Germany', 'France', 'Italy', 'Netherlands',
#        'United Kingdom', 'United States'], dtype=object)

# %%
df['Birthday'] = pd.to_datetime(df['Birthday'])

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Customers_df = df

# %%
df = pd.read_csv(r"C:\Users\saina\OneDrive\Desktop\PROJECT 2\csv files\Sales.csv")
df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.isna().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
# Out:
# Timestamp('2018-11-30 21:21:56.939126016')

# %%
not_null_df = df[df['Delivery Date'].notna()]

# %%
import pandas as pd


not_null_df['Order Date'] = pd.to_datetime(not_null_df['Order Date'])
not_null_df['Delivery Date'] = pd.to_datetime(not_null_df['Delivery Date'])

# Calculate the duration in days for rows with non-null Delivery Date
not_null_df['Duration'] = (not_null_df['Delivery Date'] - not_null_df['Order Date']).dt.days

# Calculate the average duration for non-null Delivery Dates
average_duration = not_null_df['Duration'].mean()

print("Average Duration overall:", average_duration)
average_duration_by_currency = not_null_df.groupby('Currency Code')['Duration'].mean()
print("Average duration group by currency\n" ,average_duration_by_currency)

mode_duration = not_null_df['Duration'].mode()
print("mode Duration overall:", mode_duration[0])
# Out:
# Average Duration overall: 4.529130269654386
# Average duration group by currency
#  Currency Code
# AUD    4.321789
# CAD    4.697270
# EUR    4.477682
# GBP    4.658651
# USD    4.512202
# Name: Duration, dtype: float64
# mode Duration overall: 4
# C:\Users\saina\AppData\Local\Temp\ipykernel_14092\740920727.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_null_df['Order Date'] = pd.to_datetime(not_null_df['Order Date'])
# C:\Users\saina\AppData\Local\Temp\ipykernel_14092\740920727.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
not_null_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# 5            366002          3 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62878       2243029          6 2021-02-20    2021-02-27       887764
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Duration
# 1             0        1048         2           USD        12
# ...

# %%
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'])

# %%
df.isna().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df.loc[df['Delivery Date'].isna(), 'Delivery Date'] = df['Order Date'] + pd.Timedelta(days=5)
# added 5 days to order date and assigned it to delivery data column wherever the value is null.
# because it take 5 days to deliver the order according to the average we found in previos code

# %%
df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-06       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-25      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df.isna().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
# Converted the Order Date and Delivery Date columns to datetime format.
# Calculated the average delivery duration from the rows where Delivery Date is available, which was approximately 4.53 days, rounded to 5 days.
# Imputed missing Delivery Date values by adding 5 days to the Order Date.
# This method ensures that all records have a valid Delivery Date by estimating missing values based on the average delivery duration.

# %%
Sales_df = df

# %%
Exchange_rates_df
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
Stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
Products_df
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
Customers_df
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#        State Code              State Zip Code        Country      Continent  \
# 0           False    South Australia     5523      Australia      Australia
# ...

# %%
Sales_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-06       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-25      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
Exchange_rates_df['Date'].unique()
# Out:
# <DatetimeArray>
# ['2015-01-01 00:00:00', '2015-01-02 00:00:00', '2015-01-03 00:00:00',
#  '2015-01-04 00:00:00', '2015-01-05 00:00:00', '2015-01-06 00:00:00',
#  '2015-01-07 00:00:00', '2015-01-08 00:00:00', '2015-01-09 00:00:00',
#  '2015-01-10 00:00:00',
#  ...
#  '2021-02-11 00:00:00', '2021-02-12 00:00:00', '2021-02-13 00:00:00',
#  '2021-02-14 00:00:00', '2021-02-15 00:00:00', '2021-02-16 00:00:00',
#  '2021-02-17 00:00:00', '2021-02-18 00:00:00', '2021-02-19 00:00:00',
#  '2021-02-20 00:00:00']
# Length: 2243, dtype: datetime64[ns]

# %%
Sales_df.duplicated().sum()
# Out:
# 0

# %%
Customers_df.duplicated().sum()
# Out:
# 0

# %%
Exchange_rates_df.duplicated().sum()
# Out:
# 0

# %%
Products_df.duplicated().sum()
# Out:
# 0

# %%
Stores_df.duplicated().sum()
# Out:
# 0

# %%
Stores_df['StoreKey'].duplicated().sum()
# Out:
# 0

# %%
import pandas as pd

# Assuming you have three DataFrames: Customers_df, Orders_df, Products_df

# Merge Orders_df with Customers_df on 'CustomerKey'
merged_df = pd.merge(Sales_df, Customers_df, on='CustomerKey', how='left')

# Merge the result with Products_df on 'ProductKey'
merged_df = pd.merge(merged_df, Products_df, on='ProductKey', how='left')

# Optional: Merge with another DataFrame if needed, e.g., Store_df
# merged_df = pd.merge(merged_df, Store_df, on='StoreKey', how='left')

# %%
merged_df.isna().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State Code        0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %% [markdown]
# # Merging

# %%
sales_customers_df = pd.merge(Sales_df, Customers_df, on='CustomerKey', how='left')

# %%
sales_customers_products_df = pd.merge(sales_customers_df, Products_df, on='ProductKey', how='left')

# %%
sales_products_df = pd.merge(Sales_df, Products_df, on='ProductKey', how='left')

# %%
sales_stores_df = pd.merge(Sales_df, Stores_df, on='StoreKey', how='left')

# %%
sales_stores_df
sales_products_df
sales_customers_products_df
sales_customers_df

# %%
Exchange_rates_df
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
sales_products_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-06       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-25      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  \
# 0            10        1304         1           CAD
# ...

# %%
# Merge sales_products_df with exchange_rates_df on 'Order Date' and 'Currency Code'
Sales_products_Exchangerates_df = pd.merge(
    sales_products_df,
    Exchange_rates_df[['Date', 'Currency', 'Exchange']],  # Selecting only the needed columns
    left_on=['Order Date', 'Currency Code'],  # Columns in sales_products_df
    right_on=['Date', 'Currency'],  # Columns in exchange_rates_df
    how='left'  # Use 'left' to keep all rows from sales_products_df
)

# %%
Sales_products_Exchangerates_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-06       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-25      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  \
# 0            10        1304         1           CAD
# ...

# %%
Sales_products_Exchangerates_df
sales_stores_df
sales_products_df
sales_customers_products_df
sales_customers_df

# %% [markdown]
# # MYSQL

# %%
# sales table

# %%
import mysql.connector

con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678"
)
cursor = con.cursor()

cursor.execute("create database if not exists DataSpark")
cursor.execute("use DataSpark")

query = """CREATE TABLE if not exists sales (
    Order_Number INT,
    Line_Item INT,
    Order_Date DATE,
    Delivery_Date DATE,
    Customer_Key INT,
    Store_Key INT,
    Product_Key INT,
    Quantity INT,
    Currency_Code VARCHAR(255)
)"""

cursor.execute(query)

# %%
import mysql.connector

con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()
cursor.execute("show tables")
for i in cursor:
    print(i)
# Out:
# ('products',)
# ('sales',)

# %%
Sales_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-06       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-25      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
insert_query = """
INSERT INTO sales (Order_Number, Line_Item, Order_Date, Delivery_Date, Customer_Key, Store_Key, Product_Key, Quantity, Currency_Code)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Convert DataFrame to list of tuples for insertion
data_to_insert = Sales_df.values.tolist()

# Execute insertion
cursor.executemany(insert_query, data_to_insert)

# Commit and close
con.commit()
cursor.close()
con.close()

# %%
import mysql.connector

con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()
cursor.execute("desc sales")
for i in cursor:
    print(i)
# Out:
# ('Order_Number', 'int', 'YES', '', None, '')
# ('Line_Item', 'int', 'YES', '', None, '')
# ('Order_Date', 'date', 'YES', '', None, '')
# ('Delivery_Date', 'date', 'YES', '', None, '')
# ('Customer_Key', 'int', 'YES', '', None, '')
# ('Store_Key', 'int', 'YES', '', None, '')
# ('Product_Key', 'int', 'YES', '', None, '')
# ('Quantity', 'int', 'YES', '', None, '')
# ('Currency_Code', 'varchar(255)', 'YES', '', None, '')

# %%
Products_df.columns
# Out:
# Index(['ProductKey', 'Product Name', 'Brand', 'Color', 'Unit Cost USD',
#        'Unit Price USD', 'SubcategoryKey', 'Subcategory', 'CategoryKey',
#        'Category'],
#       dtype='object')

# %%
Products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
# Products table

import mysql.connector

con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()

query = """CREATE TABLE if not exists products (
    Product_Key INT,
    Product_Name VARCHAR(255),
    Brand VARCHAR(255),
    Color VARCHAR(255),
    Unit_Cost_USD DECIMAL(10, 2),
    Unit_Price_USD DECIMAL(10, 2),
    Subcategory_Key INT,
    Subcategory VARCHAR(255),
    CategoryKey INT,
    Category VARCHAR(255)
)"""

cursor.execute(query)


insert_query = """
INSERT INTO products (Product_Key, Product_Name, Brand, Color, Unit_Cost_USD, Unit_Price_USD, Subcategory_Key, Subcategory, CategoryKey, Category)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Convert DataFrame to list of tuples for insertion
data_to_insert = Products_df.values.tolist()

# Execute insertion
cursor.executemany(insert_query, data_to_insert)


cursor.execute("desc products")
for i in cursor:
    print(i)


# Commit and close
con.commit()
cursor.close()
con.close()
# Out:
# ('Product_Key', 'int', 'YES', '', None, '')
# ('Product_Name', 'varchar(255)', 'YES', '', None, '')
# ('Brand', 'varchar(255)', 'YES', '', None, '')
# ('Color', 'varchar(255)', 'YES', '', None, '')
# ('Unit_Cost_USD', 'decimal(10,2)', 'YES', '', None, '')
# ('Unit_Price_USD', 'decimal(10,2)', 'YES', '', None, '')
# ('Subcategory_Key', 'int', 'YES', '', None, '')
# ('Subcategory', 'varchar(255)', 'YES', '', None, '')
# ('CategoryKey', 'int', 'YES', '', None, '')
# ('Category', 'varchar(255)', 'YES', '', None, '')

# %%
# customers table

# %%
import mysql.connector

# Establishing connection to MySQL
con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()

# Creating the customers table
query = """CREATE TABLE IF NOT EXISTS customers (
    Customer_Key INT,
    Gender VARCHAR(50),
    Name VARCHAR(255),
    City VARCHAR(255),
    State_Code VARCHAR(50),
    State VARCHAR(255),
    Zip_Code VARCHAR(50),
    Country VARCHAR(255),
    Continent VARCHAR(255),
    Birthday DATE
)"""
cursor.execute(query)

# Inserting data into customers table
insert_query = """
INSERT INTO customers (Customer_Key, Gender, Name, City, State_Code, State, Zip_Code, Country, Continent, Birthday)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Convert DataFrame to list of tuples for insertion
data_to_insert = Customers_df.values.tolist()

# Execute the insertion
cursor.executemany(insert_query, data_to_insert)

# Verify by describing the customers table
cursor.execute("DESC customers")
for i in cursor:
    print(i)

# Commit the changes and close the connection
con.commit()
cursor.close()
con.close()
# Out:
# ('Customer_Key', 'int', 'YES', '', None, '')
# ('Gender', 'varchar(50)', 'YES', '', None, '')
# ('Name', 'varchar(255)', 'YES', '', None, '')
# ('City', 'varchar(255)', 'YES', '', None, '')
# ('State_Code', 'varchar(50)', 'YES', '', None, '')
# ('State', 'varchar(255)', 'YES', '', None, '')
# ('Zip_Code', 'varchar(50)', 'YES', '', None, '')
# ('Country', 'varchar(255)', 'YES', '', None, '')
# ('Continent', 'varchar(255)', 'YES', '', None, '')
# ('Birthday', 'date', 'YES', '', None, '')

# %%
Customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
# stores table

# %%
Stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     float64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.7+ KB

# %%
import mysql.connector

# Establishing connection to MySQL
con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()

# Creating the stores table
query = """CREATE TABLE IF NOT EXISTS stores (
    Store_Key INT,
    Country VARCHAR(255),
    State VARCHAR(255),
    Square_Meters FLOAT,
    Open_Date DATE
)"""
cursor.execute(query)

# Inserting data into stores table
insert_query = """
INSERT INTO stores (Store_Key, Country, State, Square_Meters, Open_Date)
VALUES (%s, %s, %s, %s, %s)
"""

# Convert DataFrame to list of tuples for insertion
data_to_insert = Stores_df.values.tolist()

# Execute the insertion
cursor.executemany(insert_query, data_to_insert)

# Verify by describing the stores table
cursor.execute("DESC stores")
for i in cursor:
    print(i)

# Commit the changes and close the connection
con.commit()
cursor.close()
con.close()
# Out:
# ('Store_Key', 'int', 'YES', '', None, '')
# ('Country', 'varchar(255)', 'YES', '', None, '')
# ('State', 'varchar(255)', 'YES', '', None, '')
# ('Square_Meters', 'float', 'YES', '', None, '')
# ('Open_Date', 'date', 'YES', '', None, '')

# %%
# exchange rates table

# %%
Exchange_rates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
import mysql.connector

# Establish the connection
con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()

# Create the exchange_rates table
query = """CREATE TABLE IF NOT EXISTS exchange_rates (
    Date DATE,
    Currency VARCHAR(10),
    Exchange FLOAT
)"""

cursor.execute(query)

# Prepare the insert query
insert_query = """
INSERT INTO exchange_rates (Date, Currency, Exchange)
VALUES (%s, %s, %s)
"""

# Convert DataFrame to list of tuples for insertion
data_to_insert = Exchange_rates_df.values.tolist()

# Execute the insertion
cursor.executemany(insert_query, data_to_insert)

# Commit the transaction
con.commit()

# Close the connection
cursor.close()
con.close()

# %%
con = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="DataSpark"
)
cursor = con.cursor()
cursor.execute("DESC exchange_rates")
for i in cursor:
    print(i)
# Out:
# ('Date', 'date', 'YES', '', None, '')
# ('Currency', 'varchar(10)', 'YES', '', None, '')
# ('Exchange', 'float', 'YES', '', None, '')

# %%
cursor.execute("show tables")
for i in cursor:
    print(i)
# Out:
# ('customers',)
# ('exchange_rates',)
# ('products',)
# ('sales',)
# ('stores',)
